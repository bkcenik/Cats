# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
#from config import api_key
from pprint import pprint

# %%
url= "https://api.darksky.net/forecast/c1c29fdb57faf89ebb9b57fbd5e9772e/42.3601,-71.0589,255657600?=currently,flags"
query_url=url

# %%
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Get the temperature from the response
#print(f"The weather API responded with: {weather_json}.")
pprint(weather_json)

#temp= requests.get(url + "precipAccumulation").json()
#pprint(temp)
# set up lists to hold reponse info
#print(f"The temperature information received is: {temp}")
# Out:
# {'currently': {'apparentTemperature': 13.49,
#                'cloudCover': 1,
#                'dewPoint': 29.24,
#                'humidity': 0.95,
#                'icon': 'snow',
#                'precipIntensity': 0.1692,
#                'precipProbability': 1,
#                'precipType': 'snow',
#                'pressure': 1006.67,
#                'summary': 'Heavy Snow and Dangerously Windy',
#                'temperature': 30.38,
#                'time': 255657600,
#                'uvIndex': 0,
#                'visibility': 0.2,
#                'windBearing': 63,
#                'windGust': 83.48,
#                'windSpeed': 40.36},
#  'daily': {'data': [{'apparentTemperatureHigh': 24.87,
#                      'apparentTemperatureHighTime': 255628800,
#                      'apparentTemperatureLow': 13.84,
#                      'apparentTemperatureLowTime': 255668400,
#                      'apparentTemperatureMax': 24.87,
#                      'apparentTemperatureMaxTime': 255628800,
#                      'apparentTemperatureMin': 12.3,
#                      'apparentTemperatureMinTime': 255650400,
#                      'cloudCover': 0.95,
#                      'dewPoint': 23.74,
#                      'humidity': 0.8,
#                      'icon': 'snow',
#                      'moonPhase': 0.97,
#                      'precipAccumulation': 6.729,
#                      'precipIntensity': 0.0338,
#                      'precipIntensityMax': 0.1692,
#                      'precipIntensityMaxTime': 255657600,
#                      'precipProbability': 1,
#                      'precipType': 'snow',
#                      'pressure': 1016.48,
#                      'summary': 'Snow (9–13 in.) and dangerously windy '
#                                 'starting in the afternoon.',
#                      'sunriseTime': 255614024,
#                      'sunsetTime': 255650737,
#                      'temperatureHigh': 33.97,
#                      'temperatureHighTime': 255628800,
#                      'temperatureLow': 30,
#                      'temperatureLowTime': 255697200,
#                      'temperatureMax': 33.97,
#                      'temperatureMaxTime': 255628800,
#                      'temperatureMin': 22.53,
#                      'temperatureMinTime': 255596400,
#                      'time': 255589200,
#                      'uvIndex': 2,
#                      'uvIndexTime': 255628800,
#                      'visibility': 5.01,
#                      'windBearing': 55,
#                      'windGust': 83.79,
#                      'windGustTime': 255668400,
#                      'windSpeed': 21.01}]},
#  'flags': {'nearest-station': 0.462,
#            'sources': ['cmc',
#                        'gfs',
#                        'hrrr',
#                        'icon',
#                        'isd',
#                        'madis',
#                        'nam',
#                        'sref'],
#            'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 18.89,
#                       'cloudCover': 0.92,
#                       'dewPoint': 15.73,
#                       'humidity': 0.74,
#                       'icon': 'partly-cloudy-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1026.75,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 22.85,
#                       'time': 255589200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 350,
#                       'windSpeed': 3.04},
#                      {'apparentTemperature': 15.01,
#                       'cloudCover': 0.66,
#                       'dewPoint': 15.24,
#                       'humidity': 0.67,
#                       'icon': 'partly-cloudy-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1026.97,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 24.49,
#                       'time': 255592800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 0,
#                       'windSpeed': 9.03},
#                      {'apparentTemperature': 14.98,
#                       'cloudCover': 1,
#                       'dewPoint': 15.6,
#                       'humidity': 0.74,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1025.99,
#                       'summary': 'Overcast',
#                       'temperature': 22.53,
#                       'time': 255596400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 350,
#                       'windSpeed': 5.97},
#                      {'apparentTemperature': 14.98,
#                       'cloudCover': 0.96,
#                       'dewPoint': 15.6,
#                       'humidity': 0.74,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1025.02,
#                       'summary': 'Overcast',
#                       'temperature': 22.53,
#                       'time': 255600000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 11,
#                       'windSpeed': 5.97},
#                      {'apparentTemperature': 17.24,
#                       'cloudCover': 0.77,
#                       'dewPoint': 17.9,
#                       'humidity': 0.69,
#                       'icon': 'partly-cloudy-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1025.53,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 26.83,
#                       'time': 255603600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 59,
#                       'windSpeed': 10.14},
#                      {'apparentTemperature': 17.4,
#                       'cloudCover': 0.96,
#                       'dewPoint': 19.93,
#                       'humidity': 0.74,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1024.77,
#                       'summary': 'Overcast',
#                       'temperature': 27.1,
#                       'time': 255607200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 90,
#                       'windSpeed': 10.46},
#                      {'apparentTemperature': 17.3,
#                       'cloudCover': 0.96,
#                       'dewPoint': 19.93,
#                       'humidity': 0.73,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1024.34,
#                       'summary': 'Overcast',
#                       'temperature': 27.32,
#                       'time': 255610800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 90,
#                       'windGust': 23.01,
#                       'windSpeed': 11.19},
#                      {'apparentTemperature': 18.42,
#                       'cloudCover': 0.81,
#                       'dewPoint': 19.07,
#                       'humidity': 0.69,
#                       'icon': 'partly-cloudy-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1024.56,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 28.01,
#                       'time': 255614400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 71,
#                       'windGust': 20.73,
#                       'windSpeed': 10.68},
#                      {'apparentTemperature': 21.97,
#                       'cloudCover': 1,
#                       'dewPoint': 23.17,
#                       'humidity': 0.73,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1023.42,
#                       'summary': 'Overcast',
#                       'temperature': 30.69,
#                       'time': 255618000,
#                       'uvIndex': 0,
#                       'visibility': 6.93,
#                       'windBearing': 43,
#                       'windGust': 27.62,
#                       'windSpeed': 10.25},
#                      {'apparentTemperature': 21.67,
#                       'cloudCover': 1,
#                       'dewPoint': 26.27,
#                       'humidity': 0.79,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1022.2,
#                       'summary': 'Overcast',
#                       'temperature': 32.01,
#                       'time': 255621600,
#                       'uvIndex': 1,
#                       'visibility': 6.93,
#                       'windBearing': 42,
#                       'windGust': 31.09,
#                       'windSpeed': 14.81},
#                      {'apparentTemperature': 22.05,
#                       'cloudCover': 0.97,
#                       'dewPoint': 27,
#                       'humidity': 0.78,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1023.06,
#                       'summary': 'Overcast',
#                       'temperature': 33.14,
#                       'time': 255625200,
#                       'uvIndex': 1,
#                       'visibility': 7.7,
#                       'windBearing': 50,
#                       'windGust': 28.77,
#                       'windSpeed': 18.02},
#                      {'apparentTemperature': 24.87,
#                       'cloudCover': 1,
#                       'dewPoint': 30.95,
#                       'humidity': 0.89,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1019.63,
#                       'summary': 'Overcast',
#                       'temperature': 33.97,
#                       'time': 255628800,
#                       'uvIndex': 2,
#                       'visibility': 3.85,
#                       'windBearing': 43,
#                       'windGust': 36.5,
#                       'windSpeed': 12.96},
#                      {'apparentTemperature': 24.27,
#                       'cloudCover': 1,
#                       'dewPoint': 30.01,
#                       'humidity': 0.85,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.09,
#                       'precipIntensity': 0.0118,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1017.61,
#                       'summary': 'Light Snow and Windy',
#                       'temperature': 33.97,
#                       'time': 255632400,
#                       'uvIndex': 2,
#                       'visibility': 5.19,
#                       'windBearing': 48,
#                       'windGust': 40.86,
#                       'windSpeed': 14.55},
#                      {'apparentTemperature': 18.83,
#                       'cloudCover': 0.94,
#                       'dewPoint': 28.94,
#                       'humidity': 0.86,
#                       'icon': 'wind',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1018.14,
#                       'summary': 'Windy and Overcast',
#                       'temperature': 32.64,
#                       'time': 255636000,
#                       'uvIndex': 2,
#                       'visibility': 3.47,
#                       'windBearing': 59,
#                       'windGust': 45.13,
#                       'windSpeed': 28.26},
#                      {'apparentTemperature': 18.01,
#                       'cloudCover': 1,
#                       'dewPoint': 23.17,
#                       'humidity': 0.73,
#                       'icon': 'wind',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1014.12,
#                       'summary': 'Windy and Foggy',
#                       'temperature': 30.94,
#                       'time': 255639600,
#                       'uvIndex': 1,
#                       'visibility': 1.31,
#                       'windBearing': 36,
#                       'windGust': 45.01,
#                       'windSpeed': 22.08},
#                      {'apparentTemperature': 16.15,
#                       'cloudCover': 1,
#                       'dewPoint': 20.13,
#                       'humidity': 0.66,
#                       'icon': 'wind',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.9,
#                       'summary': 'Breezy and Overcast',
#                       'temperature': 30,
#                       'time': 255643200,
#                       'uvIndex': 1,
#                       'visibility': 2.66,
#                       'windBearing': 50,
#                       'windGust': 38.1,
#                       'windSpeed': 24.44},
#                      {'apparentTemperature': 14.46,
#                       'cloudCover': 0.93,
#                       'dewPoint': 19.08,
#                       'humidity': 0.64,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.176,
#                       'precipIntensity': 0.0197,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1012.49,
#                       'summary': 'Snow and Dangerously Windy',
#                       'temperature': 29.81,
#                       'time': 255646800,
#                       'uvIndex': 0,
#                       'visibility': 0.62,
#                       'windBearing': 66,
#                       'windGust': 55.81,
#                       'windSpeed': 30.76},
#                      {'apparentTemperature': 12.3,
#                       'cloudCover': 1,
#                       'dewPoint': 24.28,
#                       'humidity': 0.8,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.108,
#                       'precipIntensity': 0.0118,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1008.84,
#                       'summary': 'Light Snow and Dangerously Windy',
#                       'temperature': 29.54,
#                       'time': 255650400,
#                       'uvIndex': 0,
#                       'visibility': 0.5,
#                       'windBearing': 53,
#                       'windGust': 63.08,
#                       'windSpeed': 40.48},
#                      {'apparentTemperature': 12.86,
#                       'cloudCover': 1,
#                       'dewPoint': 24.46,
#                       'humidity': 0.8,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.705,
#                       'precipIntensity': 0.0788,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1006.65,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 29.86,
#                       'time': 255654000,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 55,
#                       'windGust': 60.9,
#                       'windSpeed': 39.83},
#                      {'apparentTemperature': 13.49,
#                       'cloudCover': 1,
#                       'dewPoint': 29.24,
#                       'humidity': 0.95,
#                       'icon': 'snow',
#                       'precipAccumulation': 1.458,
#                       'precipIntensity': 0.1692,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1006.67,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 30.38,
#                       'time': 255657600,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 63,
#                       'windGust': 83.48,
#                       'windSpeed': 40.36},
#                      {'apparentTemperature': 14.26,
#                       'cloudCover': 1,
#                       'dewPoint': 30.32,
#                       'humidity': 0.98,
#                       'icon': 'snow',
#                       'precipAccumulation': 1.343,
#                       'precipIntensity': 0.1614,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1002.84,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 30.87,
#                       'time': 255661200,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 55,
#                       'windGust': 79.66,
#                       'windSpeed': 39.83},
#                      {'apparentTemperature': 14.89,
#                       'cloudCover': 1,
#                       'dewPoint': 31,
#                       'humidity': 0.98,
#                       'icon': 'snow',
#                       'precipAccumulation': 1.121,
#                       'precipIntensity': 0.1417,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1001.65,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 31.55,
#                       'time': 255664800,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 54,
#                       'windGust': 83.48,
#                       'windSpeed': 41.81},
#                      {'apparentTemperature': 13.84,
#                       'cloudCover': 0.96,
#                       'dewPoint': 30.67,
#                       'humidity': 1,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.831,
#                       'precipIntensity': 0.0985,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1000.58,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 30.67,
#                       'time': 255668400,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 70,
#                       'windGust': 83.79,
#                       'windSpeed': 40.74},
#                      {'apparentTemperature': 16.78,
#                       'cloudCover': 1,
#                       'dewPoint': 32.05,
#                       'humidity': 0.98,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.897,
#                       'precipIntensity': 0.118,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1000.91,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 32.55,
#                       'time': 255672000,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 54,
#                       'windGust': 67.48,
#                       'windSpeed': 38.75}],
#             'icon': 'snow',
#             'summary': 'Snow (5–8 in.) and dangerously windy starting in the '
#                        'afternoon.'},
#  'latitude': 42.3601,
#  'longitude': -71.0589,
#  'offset': -5,
#  'timezone': 'America/New_York'}
# {'currently': {'apparentTemperature': 13.49,
#                'cloudCover': 1,
#                'dewPoint': 29.24,
#                'humidity': 0.95,
#                'icon': 'snow',
#                'precipIntensity': 0.1692,
#                'precipProbability': 1,
#                'precipType': 'snow',
#                'pressure': 1006.67,
#                'summary': 'Heavy Snow and Dangerously Windy',
#                'temperature': 30.38,
#                'time': 255657600,
#                'uvIndex': 0,
#                'visibility': 0.2,
#                'windBearing': 63,
#                'windGust': 83.48,
#                'windSpeed': 40.36},
#  'daily': {'data': [{'apparentTemperatureHigh': 24.87,
#                      'apparentTemperatureHighTime': 255628800,
#                      'apparentTemperatureLow': 13.84,
#                      'apparentTemperatureLowTime': 255668400,
#                      'apparentTemperatureMax': 24.87,
#                      'apparentTemperatureMaxTime': 255628800,
#                      'apparentTemperatureMin': 12.3,
#                      'apparentTemperatureMinTime': 255650400,
#                      'cloudCover': 0.95,
#                      'dewPoint': 23.74,
#                      'humidity': 0.8,
#                      'icon': 'snow',
#                      'moonPhase': 0.97,
#                      'precipAccumulation': 6.729,
#                      'precipIntensity': 0.0338,
#                      'precipIntensityMax': 0.1692,
#                      'precipIntensityMaxTime': 255657600,
#                      'precipProbability': 1,
#                      'precipType': 'snow',
#                      'pressure': 1016.48,
#                      'summary': 'Snow (9–13 in.) and dangerously windy '
#                                 'starting in the afternoon.',
#                      'sunriseTime': 255614024,
#                      'sunsetTime': 255650737,
#                      'temperatureHigh': 33.97,
#                      'temperatureHighTime': 255628800,
#                      'temperatureLow': 30,
#                      'temperatureLowTime': 255697200,
#                      'temperatureMax': 33.97,
#                      'temperatureMaxTime': 255628800,
#                      'temperatureMin': 22.53,
#                      'temperatureMinTime': 255596400,
#                      'time': 255589200,
#                      'uvIndex': 2,
#                      'uvIndexTime': 255628800,
#                      'visibility': 5.01,
#                      'windBearing': 55,
#                      'windGust': 83.79,
#                      'windGustTime': 255668400,
#                      'windSpeed': 21.01}]},
#  'flags': {'nearest-station': 0.462,
#            'sources': ['cmc',
#                        'gfs',
#                        'hrrr',
#                        'icon',
#                        'isd',
#                        'madis',
#                        'nam',
#                        'sref'],
#            'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 18.89,
#                       'cloudCover': 0.92,
#                       'dewPoint': 15.73,
#                       'humidity': 0.74,
#                       'icon': 'partly-cloudy-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1026.75,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 22.85,
#                       'time': 255589200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 350,
#                       'windSpeed': 3.04},
#                      {'apparentTemperature': 15.01,
#                       'cloudCover': 0.66,
#                       'dewPoint': 15.24,
#                       'humidity': 0.67,
#                       'icon': 'partly-cloudy-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1026.97,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 24.49,
#                       'time': 255592800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 0,
#                       'windSpeed': 9.03},
#                      {'apparentTemperature': 14.98,
#                       'cloudCover': 1,
#                       'dewPoint': 15.6,
#                       'humidity': 0.74,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1025.99,
#                       'summary': 'Overcast',
#                       'temperature': 22.53,
#                       'time': 255596400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 350,
#                       'windSpeed': 5.97},
#                      {'apparentTemperature': 14.98,
#                       'cloudCover': 0.96,
#                       'dewPoint': 15.6,
#                       'humidity': 0.74,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1025.02,
#                       'summary': 'Overcast',
#                       'temperature': 22.53,
#                       'time': 255600000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 11,
#                       'windSpeed': 5.97},
#                      {'apparentTemperature': 17.24,
#                       'cloudCover': 0.77,
#                       'dewPoint': 17.9,
#                       'humidity': 0.69,
#                       'icon': 'partly-cloudy-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1025.53,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 26.83,
#                       'time': 255603600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 59,
#                       'windSpeed': 10.14},
#                      {'apparentTemperature': 17.4,
#                       'cloudCover': 0.96,
#                       'dewPoint': 19.93,
#                       'humidity': 0.74,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1024.77,
#                       'summary': 'Overcast',
#                       'temperature': 27.1,
#                       'time': 255607200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 90,
#                       'windSpeed': 10.46},
#                      {'apparentTemperature': 17.3,
#                       'cloudCover': 0.96,
#                       'dewPoint': 19.93,
#                       'humidity': 0.73,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1024.34,
#                       'summary': 'Overcast',
#                       'temperature': 27.32,
#                       'time': 255610800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 90,
#                       'windGust': 23.01,
#                       'windSpeed': 11.19},
#                      {'apparentTemperature': 18.42,
#                       'cloudCover': 0.81,
#                       'dewPoint': 19.07,
#                       'humidity': 0.69,
#                       'icon': 'partly-cloudy-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1024.56,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 28.01,
#                       'time': 255614400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 71,
#                       'windGust': 20.73,
#                       'windSpeed': 10.68},
#                      {'apparentTemperature': 21.97,
#                       'cloudCover': 1,
#                       'dewPoint': 23.17,
#                       'humidity': 0.73,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1023.42,
#                       'summary': 'Overcast',
#                       'temperature': 30.69,
#                       'time': 255618000,
#                       'uvIndex': 0,
#                       'visibility': 6.93,
#                       'windBearing': 43,
#                       'windGust': 27.62,
#                       'windSpeed': 10.25},
#                      {'apparentTemperature': 21.67,
#                       'cloudCover': 1,
#                       'dewPoint': 26.27,
#                       'humidity': 0.79,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1022.2,
#                       'summary': 'Overcast',
#                       'temperature': 32.01,
#                       'time': 255621600,
#                       'uvIndex': 1,
#                       'visibility': 6.93,
#                       'windBearing': 42,
#                       'windGust': 31.09,
#                       'windSpeed': 14.81},
#                      {'apparentTemperature': 22.05,
#                       'cloudCover': 0.97,
#                       'dewPoint': 27,
#                       'humidity': 0.78,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1023.06,
#                       'summary': 'Overcast',
#                       'temperature': 33.14,
#                       'time': 255625200,
#                       'uvIndex': 1,
#                       'visibility': 7.7,
#                       'windBearing': 50,
#                       'windGust': 28.77,
#                       'windSpeed': 18.02},
#                      {'apparentTemperature': 24.87,
#                       'cloudCover': 1,
#                       'dewPoint': 30.95,
#                       'humidity': 0.89,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1019.63,
#                       'summary': 'Overcast',
#                       'temperature': 33.97,
#                       'time': 255628800,
#                       'uvIndex': 2,
#                       'visibility': 3.85,
#                       'windBearing': 43,
#                       'windGust': 36.5,
#                       'windSpeed': 12.96},
#                      {'apparentTemperature': 24.27,
#                       'cloudCover': 1,
#                       'dewPoint': 30.01,
#                       'humidity': 0.85,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.09,
#                       'precipIntensity': 0.0118,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1017.61,
#                       'summary': 'Light Snow and Windy',
#                       'temperature': 33.97,
#                       'time': 255632400,
#                       'uvIndex': 2,
#                       'visibility': 5.19,
#                       'windBearing': 48,
#                       'windGust': 40.86,
#                       'windSpeed': 14.55},
#                      {'apparentTemperature': 18.83,
#                       'cloudCover': 0.94,
#                       'dewPoint': 28.94,
#                       'humidity': 0.86,
#                       'icon': 'wind',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1018.14,
#                       'summary': 'Windy and Overcast',
#                       'temperature': 32.64,
#                       'time': 255636000,
#                       'uvIndex': 2,
#                       'visibility': 3.47,
#                       'windBearing': 59,
#                       'windGust': 45.13,
#                       'windSpeed': 28.26},
#                      {'apparentTemperature': 18.01,
#                       'cloudCover': 1,
#                       'dewPoint': 23.17,
#                       'humidity': 0.73,
#                       'icon': 'wind',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1014.12,
#                       'summary': 'Windy and Foggy',
#                       'temperature': 30.94,
#                       'time': 255639600,
#                       'uvIndex': 1,
#                       'visibility': 1.31,
#                       'windBearing': 36,
#                       'windGust': 45.01,
#                       'windSpeed': 22.08},
#                      {'apparentTemperature': 16.15,
#                       'cloudCover': 1,
#                       'dewPoint': 20.13,
#                       'humidity': 0.66,
#                       'icon': 'wind',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.9,
#                       'summary': 'Breezy and Overcast',
#                       'temperature': 30,
#                       'time': 255643200,
#                       'uvIndex': 1,
#                       'visibility': 2.66,
#                       'windBearing': 50,
#                       'windGust': 38.1,
#                       'windSpeed': 24.44},
#                      {'apparentTemperature': 14.46,
#                       'cloudCover': 0.93,
#                       'dewPoint': 19.08,
#                       'humidity': 0.64,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.176,
#                       'precipIntensity': 0.0197,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1012.49,
#                       'summary': 'Snow and Dangerously Windy',
#                       'temperature': 29.81,
#                       'time': 255646800,
#                       'uvIndex': 0,
#                       'visibility': 0.62,
#                       'windBearing': 66,
#                       'windGust': 55.81,
#                       'windSpeed': 30.76},
#                      {'apparentTemperature': 12.3,
#                       'cloudCover': 1,
#                       'dewPoint': 24.28,
#                       'humidity': 0.8,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.108,
#                       'precipIntensity': 0.0118,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1008.84,
#                       'summary': 'Light Snow and Dangerously Windy',
#                       'temperature': 29.54,
#                       'time': 255650400,
#                       'uvIndex': 0,
#                       'visibility': 0.5,
#                       'windBearing': 53,
#                       'windGust': 63.08,
#                       'windSpeed': 40.48},
#                      {'apparentTemperature': 12.86,
#                       'cloudCover': 1,
#                       'dewPoint': 24.46,
#                       'humidity': 0.8,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.705,
#                       'precipIntensity': 0.0788,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1006.65,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 29.86,
#                       'time': 255654000,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 55,
#                       'windGust': 60.9,
#                       'windSpeed': 39.83},
#                      {'apparentTemperature': 13.49,
#                       'cloudCover': 1,
#                       'dewPoint': 29.24,
#                       'humidity': 0.95,
#                       'icon': 'snow',
#                       'precipAccumulation': 1.458,
#                       'precipIntensity': 0.1692,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1006.67,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 30.38,
#                       'time': 255657600,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 63,
#                       'windGust': 83.48,
#                       'windSpeed': 40.36},
#                      {'apparentTemperature': 14.26,
#                       'cloudCover': 1,
#                       'dewPoint': 30.32,
#                       'humidity': 0.98,
#                       'icon': 'snow',
#                       'precipAccumulation': 1.343,
#                       'precipIntensity': 0.1614,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1002.84,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 30.87,
#                       'time': 255661200,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 55,
#                       'windGust': 79.66,
#                       'windSpeed': 39.83},
#                      {'apparentTemperature': 14.89,
#                       'cloudCover': 1,
#                       'dewPoint': 31,
#                       'humidity': 0.98,
#                       'icon': 'snow',
#                       'precipAccumulation': 1.121,
#                       'precipIntensity': 0.1417,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1001.65,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 31.55,
#                       'time': 255664800,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 54,
#                       'windGust': 83.48,
#                       'windSpeed': 41.81},
#                      {'apparentTemperature': 13.84,
#                       'cloudCover': 0.96,
#                       'dewPoint': 30.67,
#                       'humidity': 1,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.831,
#                       'precipIntensity': 0.0985,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1000.58,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 30.67,
#                       'time': 255668400,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 70,
#                       'windGust': 83.79,
#                       'windSpeed': 40.74},
#                      {'apparentTemperature': 16.78,
#                       'cloudCover': 1,
#                       'dewPoint': 32.05,
#                       'humidity': 0.98,
#                       'icon': 'snow',
#                       'precipAccumulation': 0.897,
#                       'precipIntensity': 0.118,
#                       'precipProbability': 1,
#                       'precipType': 'snow',
#                       'pressure': 1000.91,
#                       'summary': 'Heavy Snow and Dangerously Windy',
#                       'temperature': 32.55,
#                       'time': 255672000,
#                       'uvIndex': 0,
#                       'visibility': 0.2,
#                       'windBearing': 54,
#                       'windGust': 67.48,
#                       'windSpeed': 38.75}],
#             'icon': 'snow',
#             'summary': 'Snow (5–8 in.) and dangerously windy starting in the '
#                        'afternoon.'},
#  'latitude': 42.3601,
#  'longitude': -71.0589,
#  'offset': -5,
#  'timezone': 'America/New_York'}
